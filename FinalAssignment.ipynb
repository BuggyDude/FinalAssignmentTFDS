# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Emilio__<br>
# Student

# %% [markdown]
# _I am interested in data science because I like working with data._

# %% [markdown]
# ### Prints the result of the sum of two numbers.

# %%
def sum(a,b):
    return a+b
print(sum(1,2))
# Out:
# 3

# %% [markdown]
# - Bulleted List
#     - This is item 1
#     - This is item 2
# 1. Numbered List
#     1. Item 1
#     1. Item 2
#     1. Item 3
# <br>
# ***
# After horizontal line
#
# [This is a link](www.google.com)
